# %% [markdown]
# - input/output
# - variables
# - array/list
# - conditional
# - loop
# - functions

# %%
name=input('Enter name')

# %%
name=print('My name is Shibli')
# Out:
# My name is Shibli

# %%
print(name)
# Out:
# Shibli

# %% [markdown]
# Varibles

# %%
num = 213424354425

# %%
num
# Out:
# 213424354425

# %%
num + 10
# Out:
# 213424354435

# %%
num - 10
# Out:
# 213424354415

# %%
num / 10
# Out:
# 21342435442.5

# %%
num * 10
# Out:
# 2134243544250
