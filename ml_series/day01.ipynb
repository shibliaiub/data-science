# %% [markdown]
# - input/output
# - variables
# - array/list
# - conditional
# - loop
# - functions

# %%
name=input('Enter name')

# %%
name=print('My name is Shibli')
# Out:
# My name is Shibli

# %%
print(name)
# Out:
# Shibli

# %% [markdown]
# Varibles

# %%
num = 213424354425

# %%
num
# Out:
# 213424354425

# %%
num + 10
# Out:
# 213424354435

# %%
num - 10
# Out:
# 213424354415

# %%
num / 10
# Out:
# 21342435442.5

# %%
num * 10
# Out:
# 2134243544250

# %%
num = input()

# %%
num
# Out:
# '105'

# %%
num +10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 num +10
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(num)
# Out:
# str

# %%
num = 10 
type(num)
# Out:
# int

# %%
integer = 1523542
float = 2325234534.2343
string = 'rfgreteferwgf'

# %%
type(integer)
# Out:
# int

# %%
type(float)
# Out:
# float

# %%
type(str)
# Out:
# type

# %%
type(string)
# Out:
# str

# %%
num = input()

# %%
num
# Out:
# '32'

# %%
int(num)
# Out:
# 32

# %%
type(num)
# Out:
# str

# %%
num=int(num)

# %%
type(num)
# Out:
# int

# %%
num= num+10

# %%
num
# Out:
# 42
